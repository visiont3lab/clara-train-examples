# %% [markdown]
# # AI Assisted Annotation with OHIF
#
# Zero foot print Dicom viewers are ideal for radiology workflow.
# [Open Health Imaging Foundation (OHIF)](http://ohif.org/) Viewer is an open source, web-based, medical imaging viewer.
# It can be configured to connect to Image Archives that support DicomWeb,
# and offers support for mapping to proprietary API formats.
# OHIF maintained extensions add support for viewing, annotating,
# and reporting on DICOM images in 2D (slices) and 3D (volumes).
# OHIF by it self is a web viewer that requires a PACS on the back end to hold the dicom images.
# You can use either [Dcm4chee](https://github.com/dcm4che/dcm4chee-arc-light/wiki) or [Orthanc](https://www.orthanc-server.com/).
#
# For this we expand on how to use OHIF with AIAA.
# This note book will guide your through how to set up
# - OHIF web viewer with Nvidia AIAA integration
# - Orthanc
# - This current notebooks

# %% [markdown]
# ## Prerequisites
# - Nvidia GPU with 8Gb of memory
# - Going through [AIAA Notebook](AIAA.ipynb) to get basic understanding of AIAA.
# - For trouble shot, basic understanding of docker and docker compose is recommended

# %% [markdown]
# # 0. Licensing
#
# ### 0.1 ORTHANC License
# This note book will help you set up ORTHANC as a pacs back end to OHIF.
# Please read through the license of ORTHANC and its plugins
# https://book.orthanc-server.com/faq/licensing.html
#
# Please note: ORTHANC has plugins which in turn has more restrictive licenses as
# - Orthanc Core: GPL v3 https://hg.orthanc-server.com/orthanc/file/tip/COPYING
# - Web viewer: AGPL v3 https://hg.orthanc-server.com/orthanc-webviewer/file/tip/COPYING
# - PostgreSQL Support: AGPL v3 https://hg.orthanc-server.com/orthanc-postgresql/file/tip/COPYING
# - DICOMweb Support: AGPL v3 https://hg.orthanc-server.com/orthanc-dicomweb/file/tip/COPYING
# - Whole slide imaging: AGPL v3 https://hg.orthanc-server.com/orthanc-wsi/file/tip/COPYING
#
# ORTHANC will be pulled as a docker image as it is specified in the docker compose file
# ```
#   orthanc:
#     image: jodogne/orthanc-plugins:1.9.1 # Orthanc docker image with plugins
# ```
# ### 0.2 Nginx License
# Docker compose will set up OHIF which in turn uses [Nginx](https://nginx.org/en/)
# from their website it states
# "The sources and documentation are distributed under the [2-clause BSD-like license](https://nginx.org/LICENSE)"

# %% [markdown]
# ## 1. Setup OHIF
# Nvidia has integrated AIAA into OHIF as a plugin.
# We have packaged all under OHIF-Orthanc sub-folder.
# This will launch OHIF with Orthanc and this current notebooks.<br>
# **Note: You need to close this docker container before doing steps below.
# You can do this by running `scripts/stopClaraTrainNoteBooks.sh`** <br>
# These steps will launch multiple dockers as shown below
# <br><img src="screenShots/ThreeDockers.png" alt="Drawing" style="height: 300px;"/><br>
#
# 1. Open terminal on your bare bone host
# 2. cd into `AIAA/OHIF-Orthanc` sub-folders
# 3. (optional) edit docker-compose.yml to change/ map the data dir.
# By default it will be inside the sub-folder.
# You can simply change the `ConfigLocalPath=./data` in the `.env` file.
# 4. Run `./restart.sh`. This will launch this notebooks, OHIF, and orthanc
# 5. Basic authentication is provided.

# %% [markdown]
# ### 1.2. Check that everything is running:
# Your main landing page is [yourip:3030/start/](http://localhost:3030/start/).
# User/password is `clara/clara`.
# To change this user/password please refer to exercise section below.
# You should see a page as below with links as listed below
# <br><img src="screenShots/OHIFmainPage.png" alt="Drawing" style="height: 300px;"/><br>
#
#
# 1. This Notebooks: </br>
# Go to your browser at [yourip:3030/notebooks/](http://localhost:3030/notebooks/)
# and use the token printed out after running the `restart.sh` script
# 2. OHIF: </br>
# Go to your browser [yourip:3030](http://localhost:3030/) to see OHIF web page as below
# <br><img src="screenShots/OHIFList.png" alt="Drawing" style="height: 300px;"/><br>
# 3. Orthanc: </br>
# Go to your browser at [yourip:3030/pacs-admin/](http://localhost:3030/pacs-admin) to see Orthanc web UI (username/password is orthanc/orthanc)
# <br><img src="screenShots/Orthanc.png" alt="Drawing" style="height: 300px;"/><br>

# %% [markdown]
# ## 2. Download Dicom Studies
#
# OHIF and the back end PACS uses dicom format.
# For this you need to have a some Dicom studies locally.
# You can run [TCIA Notebook](../Data/TCIA/TCIADownloader.ipynb)
# with any of the sample data links.
# For basic workflow you can stop right after you download the dicom data and unzipping it.
#
# You should find the downloaded data under `/claraDevDay/Data/<Dataname>/DCM/`

# %% [markdown]
# ## 3. Upload a dicom study into the PACS (orthanc)
# Now that you have dicom images,
# we would want to upload it to our PACS.
# For this we can use dcmtk library

# %%
# install apt-get install dcmtk
# !apt-get -y install dcmtk
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libdcmtk14 libwrap0
# The following NEW packages will be installed:
#   dcmtk libdcmtk14 libwrap0
# 0 upgraded, 3 newly installed, 0 to remove and 52 not upgraded.
# Need to get 5592 kB of archives.
# After this operation, 26.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 libwrap0 amd64 7.6.q-30 [46.3 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libdcmtk14 amd64 3.6.4-2.1build2 [4682 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 dcmtk amd64 3.6.4-2.1build2 [864 kB]
# Fetched 5592 kB in 1s (8102 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 3.)
# debconf: falling back to frontend: Readline
# Selecting previously unselected package libwrap0:amd64.
# (Reading database ... 38988 files and directories currently installed.)
# Preparing to unpack .../libwrap0_7.6.q-30_amd64.deb ...
# Unpacking libwrap0:amd64 (7.6.q-30) ...
# Selecting previously unselected package libdcmtk14.
# Preparing to unpack .../libdcmtk14_3.6.4-2.1build2_amd64.deb ...
# Unpacking libdcmtk14 (3.6.4-2.1build2) ...
# Selecting previously unselected package dcmtk.
# Preparing to unpack .../dcmtk_3.6.4-2.1build2_amd64.deb ...
# Unpacking dcmtk (3.6.4-2.1build2) ...
# Setting up libwrap0:amd64 (7.6.q-30) ...
# Setting up libdcmtk14 (3.6.4-2.1build2) ...
# Setting up dcmtk (3.6.4-2.1build2) ...
# Adding `dcmtk' group to system ...
# Adding `dcmtk' user to system ...
# adduser: Warning: The home directory `/var/lib/dcmtk/db' does not belong to the user you are currently creating.
# Processing triggers for libc-bin (2.31-0ubuntu9.1) ...
# /sbin/ldconfig.real: File /lib/x86_64-linux-gnu/libnvidia-ml.so.418.126.02 is empty, not checked.
# /sbin/ldconfig.real: File /lib/x86_64-linux-gnu/libnvidia-opticalflow.so.418.126.02 is empty, not checked.
# /sbin/ldconfig.real: File /lib/x86_64-linux-gnu/libnvidia-encode.so.418.126.02 is empty, not checked.
# /sbin/ldconfig.real: File /lib/x86_64-linux-gnu/libnvidia-ptxjitcompiler.so.418.126.02 is empty, not checked.
# /sbin/ldconfig.real: File /lib/x86_64-linux-gnu/libnvidia-cfg.so.418.126.02 is empty, not checked.
# /sbin/ldconfig.real: File /lib/x86_64-linux-gnu/libnvidia-fatbinaryloader.so.418.126.02 is empty, not checked.
# /sbin/ldconfig.real: File /lib/x86_64-linux-gnu/libnvidia-compiler.so.418.126.02 is empty, not checked.
# /sbin/ldconfig.real: File /lib/x86_64-linux-gnu/libcuda.so.418.126.02 is empty, not checked.
# /sbin/ldconfig.real: File /lib/x86_64-linux-gnu/libnvcuvid.so.418.126.02 is empty, not checked.
# /sbin/ldconfig.real: File /lib/x86_64-linux-gnu/libnvidia-opencl.so.418.126.02 is empty, not checked.

# %% [markdown]
# As we are using docker compose internal network we can directly upload to orthanc using its intenal name
# `orthanc` and its internal port 4242

# %%
# !storescu -v +sd +r -xb -v -aet "fromtest" -aec "ORTHANC" orthanc 4242 /claraDevDay/Data/NSCLC_5/DCM/1.3*
# Out:
# I: determining input files ...
# I: checking input files ...
# I: Requesting Association
# I: Association Accepted (Max Send PDV: 16372)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/2-000aa68743ac744a0745d016d96d837b.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 1, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/87-7c837c1b5313a1b439d7aece29f3908d.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 2, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/17-26f3789a7e51d2b0810120854105c520.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 3, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/32-8fd947eb8b83c7533796ca756d474068.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 4, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/111-5e5aa0fc7b57bdee8e687f0b0fc48515.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 5, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/41-a59cbf08f6f919987f315f6c877d3213.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 6, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/98-35b143865b721b8a08ee510ba44059b2.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 7, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/13-c5120abe89e89968fa261ead5a0c16f5.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 8, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/40-37078e742cf144c943646e13c5e5c134.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 9, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/47-115b03ec56fb39a34374cd75e0a71a88.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 10, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/80-cac4f156aabbe4b3ffedfbba6a989c8d.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 11, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/57-17950f52946420286ea475bd4e54248a.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 12, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/34-59b600d26b371764522820a9867012a9.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 13, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/81-503e95652007afe0d9ccb4d73a59773c.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 14, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/35-f2c3a01f84c6de11cd09db68f90edd44.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 15, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/60-2038bad55039d28e6a0b359db2d83b65.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 16, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/58-85786b68b4d70faf5bc0c85e6f2463cd.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 17, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/91-dfe8a90dd393e7c9cded7d5842c54c79.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 18, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/50-247edc202dc40349c67579274d2731a8.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 19, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/12-2bec62503e31b563c6ad4a91541b7646.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 20, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/37-9adc8a882df8267eb2758801fb8e8e82.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 21, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/88-8c323e62ddb798d01f500faf9cdc554a.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 22, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/19-11baaec0d71e541d1fa804dd33a61281.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 23, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/64-f58b98d73cf4417630d6ccc5aa2ee55c.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 24, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/20-6349718e7c995bf8b5f9060700a461ea.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 25, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/44-31db3ff95176a184919302e877a356ee.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 26, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/61-27c3314dfe9a5b9cf5030b67cefbdb28.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 27, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/66-8f5e83c19af18ad803829d398e1d87ef.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 28, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/65-2ed7c9a1917045d040bc1cf384b5cf4f.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 29, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/84-3d61beabe0af5a979fa374fd9c58bd56.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 30, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/22-d94136e67ae95578f2c43196ddc4ed0a.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 31, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/110-1a3b7f2e416dc12a92e36e004ba4bbe6.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 32, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/82-41fa53a6169bef83f36715b67d8eb547.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 33, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/48-07e5194bd892e098bc3bd2c0f7a30adf.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 34, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.232988001551799080335895423941323261228/45-239ecf9ece329459db4d2e34e9ab6fdc.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID
CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Sending file: /claraDevDay/Data/NSCLC_5/DCM/1.3.6.1.4.1.32722.99.99.34905847539837720676301269477428468747/63-5caf2af2bef772592b5519a61460bac6.dcm
# I: Converting transfer syntax: Little Endian Implicit -> Big Endian Explicit
# I: Sending Store Request (MsgID 557, CT)
# XMIT: .................................
# I: Received Store Response (Success)
# I: Releasing Association

# %% [markdown]
# ## 4. Start AIAA server
# You should run the [AIAA Notebook](AIAA.ipynb) and start the AIAA server, then load at least one model.
# We recommend the 2D deepgrow model as a start.

# %% [markdown]
# ## 5. Open OHIF and use AIAA
# Now that we have dicom data in our PACS, you can open OHIF in your browser and click on a patient to view it as below.
# <br><img src="screenShots/OHIF.png" alt="Drawing" style="height: 300px;"/><br>
#
#
# Next you need to setup the AIAA plugin (see image below) :
# 1. AIAA server url:
#     1. Set to `http://<yourmachineIP>:3030/aiaa/`
#     2. Click refresh icon next to it.
#     3. You should see the models you have loaded in AIAA server.
# 2. Setup fetch from pacs:
#     1. Under more AIAA setup
#     2. Check Fetch Images From Dicom Server
#     3. Dicom server = `orthanc:4242`. This is the internal port exposed through docker network
#     4. Set AETitle = `ORTHANC`
# <br><img src="screenShots/OHIF-AIAAwRevProxy.png" alt="Drawing" style="height: 300px;"/><br>

# %% [markdown]
# ## 6. Stop All
# To stop all dockers (Notebooks, OHIF and PACS) you should run `./stop.sh`.
# ***Note: Running cell below would terminate this notebook***

# %%
#Note: Running cell below would terminate this notebook
#!./stop.sh`

# %% [markdown]
# # Exercise

# %% [markdown]
# ### 1. Remove user/password
# In order to have no security at all, you can change the [docker-compose](OHIF-Orthanc/docker-compose.yml)
# to use [nginxNoPassword](OHIF-Orthanc/config/nginxNoPassword.conf) instead of [nginxWPassword](OHIF-Orthanc/config/nginxWPassword.conf)

# %% [markdown]
# ### 2. Change user/password file
# We provide basic authentication file [`.htpasswd`](OHIF-Orthanc/config/.htpasswd)
# with user/password = clara/clara.
# In order to change this or create a new file altogether, you can run

# %%
htpasswd -c /claraDevDay/AIAA/OHIF-Orthanc/config/.MyNewhtpasswd username1
# you would be prompt for password then again to confirm it

# %% [markdown]
# To a add another user we can use the same command without `-c` flag as

# %%
htpasswd /claraDevDay/AIAA/OHIF-Orthanc/config/.MyNewhtpasswd anotherusername2

# %% [markdown]
# ### 3. Use https instead of http
# Setup above is using http for simplicity that would work on internal secure network.
# In order to use this setup on public you should use https to secure communication between client and server.
# For this we would need to:
# 1. Have a ssl certification and key. For this you can:
#     1. Use the sample self certified crt and key files provided
#     2. Use your own ssl files
#     3. Generate your own self signed by running
#     ```
#     openssl req -x509 -nodes -days 365 -newkey rsa:2048 -keyout /claraDevDay/AIAA/OHIF-Orthanc/config/nginx-selfsigned.key -out /claraDevDay/AIAA/OHIF-Orthanc/config/nginx-selfsigned.crt
#     ```
#     For more options you can follow instructions [here](https://www.digitalocean.com/community/tutorials/how-to-create-a-self-signed-ssl-certificate-for-nginx-in-ubuntu-16-04)
# 2. Change the [docker-compose.yml](OHIF-Orthanc/docker-compose.yml) to:
#     1. Map port 443 instead of port 80
#     2. Map the crt and key files.
#     3. Use [`nginxHttpsWPassword.conf`](OHIF-Orthanc/config/nginxHttpsWPassword.conf)

# %% [markdown]
# If you use self signed certification would would get warnings on your first access as shown below.
# You would need to click `Advanced` then click `Proceed to _____ (unsafe)` link as shown below
#
# <br><img src="screenShots/httpsWarning.png" alt="Drawing" style="height: 300px;"/><br>
